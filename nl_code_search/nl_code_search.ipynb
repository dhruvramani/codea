# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive

drive.mount("/content/drive")
# %cd /content/drive/My Drive/Startup/project/nl_code_search

# %%
# !pip3 install numpy more_itertools gdown
# !pip3 install torch pytorch_lightning transformers

# %% [markdown]
# Run commands below.

# %%
# %autoreload
#%cd ./pretrained_codebert/
# !sudo python3 train.py
