# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive

drive.mount("/content/drive")
# %cd /content/drive/My Drive/Startup/code/code_summ

# Next 2 for the TPU - remove if it's not a TPU runtime.
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o /root/.cache/pytorch-xla-env-setup.py
# !python /root/.cache/pytorch-xla-env-setup.py --version nightly --apt-packages libomp5 libopenblas-dev

# !pip3 install torch transformers pytorch-lightning datasets pandas autopep8 rouge_score bleu onnx onnxruntime

# %% [markdown]
# Run commands below.

# %%
# %autoreload 2
# %cd code_summ/
# !sudo python3 test.py --resume_ckpt "pretrained.ckpt"
# Out:
# 2021-03-04 11:40:59.006676: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Enter input :

# %%
# %autoreload 2
# %cd code_summ/
# !sudo python3 infer.py
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file 'infer.py': [Errno 107] Transport endpoint is not connected

# %%
# %autoreload 2
# %cd ../
# !sudo python3 prod_onnx.py --ckpt_file "pretrained.ckpt"
# Out:
# 2021-03-04 14:21:15.140132: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Model loaded from  /content/drive/My Drive/Startup/save/code_summ_models/python/p_codebert_codebert_summ/v0.0/pretrained.ckpt
# Found input input_ids with shape: {0: 'batch', 1: 'sequence'}
# Found input attention_mask with shape: {0: 'batch', 1: 'sequence'}
# Found output output_0 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_1 with shape: {0: 'batch'}
# Found output output_2 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_3 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_4 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_5 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_6 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_7 with shape: {0: 'batch', 1: 'sequence'}
# Found output output_8 with shape: {0: 'batch', 1: 'sequence'}
# ...

# %%
drive.flush_and_unmount()

# %%
# Download Pretrained model
# !pip install gdown \
  && gdown "https://drive.google.com/uc?id=1YrkwfM-0VBCJaa9NYaXUQPODdGPsmQY4" \
  -O ../../save/code_summ_models/pytorch_model.bin
