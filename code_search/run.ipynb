# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive

drive.mount("/content/drive")
# %cd /content/drive/My Drive/Startup/code/code_search

# Next 2 for the TPU - remove if it's not a TPU runtime.
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o /root/.cache/pytorch-xla-env-setup.py
# !python /root/.cache/pytorch-xla-env-setup.py --version nightly --apt-packages libomp5 libopenblas-dev

# !pip3 install torch transformers pytorch-lightning datasets pandas autopep8

# %% [markdown]
# Run commands below.

# %%
# %autoreload 2
# !sudo python3 train.py --resume_ckpt "epoch=7-step=206087.ckpt" #--gpus -1 --precision 16
# !sudo python3 test.py --resume_ckpt "epoch=7-step=206087.ckpt"
