# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive
from getpass import getpass

drive.mount("/content/drive")
# %cd /content/drive/My Drive/Startup/code

uname = "dhruvramani"

# !git config --global user.email "dhruvramani98@gmail.com"
# !git config --global user.name "$uname"

# %% [markdown]
# Pull Repo

# %%
password = getpass('Github Password : ')

# !git remote set-url origin https://$uname:$password@github.com/$uname/codea.git
# !git pull origin master
del password
# !git remote set-url origin https://github.com/$uname/codea.git

# %% [markdown]
# Use the cells below to work on the project.

# %%
# !pip3 install transformers onnx onnxruntime #torch pytorch-lightning datasets pandas autopep8

# %%
# %load_ext autoreload
# %autoreload 2
import os, sys
import onnxruntime

BASE_DIR = "/content/drive/My Drive/Startup/code/"
CODE_PATH = os.path.join(BASE_DIR, "code_summ/")
MODEL_PATH = "/content/drive/My Drive/Startup/save/onnx_models/code_summ/p_codebert-summ-" 

sys.path.append(CODE_PATH)
sys.path.append(BASE_DIR)
from code_summ.infer import infer, _model #get_model
# from code_search.infer import get_model, infer
# from dataset_scripts.utils import get_tokenizer

# tokenizer = get_tokenizer(model='p_codebert')
from transformers import RobertaTokenizer
tokenizer = RobertaTokenizer.from_pretrained('microsoft/codebert-base')
e_path = "/content/drive/My Drive/Startup/save/onnx_models/code_summ/code_summ-p_codebert-pretrained.onnx" #f'{MODEL_PATH}encoder.onnx'
dec_path = "/content/drive/My Drive/Startup/save/onnx_models/code_summ/p_codebert-summ-decoder.onnx"
de_path = f'{MODEL_PATH}dense-optim-quant.onnx'
lm_path = f'{MODEL_PATH}lm_head-optim-quant.onnx'

torch_model_path = "/content/drive/My Drive/Startup/save/code_summ_models/pytorch_model.bin"

decoder = onnxruntime.InferenceSession(dec_path)
#model = get_model(e_path, dec_path, de_path, lm_path, tokenizer)
model = _model(tokenizer, torch_model_path)

code1 = input("Enter code 1: ")
# code2 = input("Enter code 2: ")
# query = input("Enter query: ")
# summ = infer([query], [code1, code2], model, tokenizer)
# enc_input = tokenizer(code1, return_tensors='pt')
# ips = {'input_ids': enc_input['input_ids'], 'attention_mask': enc_input['attention_mask']}
# # summ = model.run(None, ips)
# print([input.name for input in decoder.get_inputs()])

infer(code1, model, tokenizer)
# print(summ)

# %%
import os, sys
sys.path.append(os.getcwd())
# !sudo python3 dataset_scripts/codesearch_uni.py

# %%
drive.flush_and_unmount()

# %% [markdown]
# Push Repo

# %%
password = getpass('Github Password : ')
# !git remote set-url origin https://$uname:$password@github.com/$uname/codea.git
# !git add .
# !git commit -am "From GDrive - probably debugged something."
# !git push origin master

del password
# !git remote set-url origin https://github.com/$uname/codea.git

# %% [markdown]
# For setting up a ssh connection.

# %%
# !pip install colab_ssh --upgrade
from colab_ssh import launch_ssh, init_git

ngrok_token = getpass("Enter ngrok token : ")
ssh_psswd = getpass("Enter the password for SSH connection : ")

launch_ssh(ngrok_token, ssh_psswd)
