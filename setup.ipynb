# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive

drive.mount("/content/drive")
# %cd /content/drive/My Drive/Startup/project

uname = "dhruvramani"

# !git config --global user.email "dhruvramani98@gmail.com"
# !git config --global user.name "$uname"

from getpass import getpass
# password = getpass('Github Password : ')

# !git remote set-url origin https://$uname:$password@github.com/$uname/codea.git
# !git pull origin master
# del password
# !git remote set-url origin https://github.com/$uname/codea.git
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Startup/project

# %%
# !pip install colab_ssh --upgrade
from colab_ssh import launch_ssh, init_git

ngrok_token = getpass("Enter ngrok token : ")
ssh_psswd = getpass("Enter the password for SSH connection : ")

launch_ssh(ngrok_token, ssh_psswd)

# %% [markdown]
# Use the cells below to work on the project.

# %%
password = getpass('Github Password : ')
# !git remote set-url origin https://$uname:$password@github.com/$uname/codea.git
# !git commit -am "From GDrive - debugged pretri"
# !git push origin master

# IMPORTANT - DON'T REMOVE THE LINE BELOW, unless you wanna show off your password
del password
# !git remote set-url origin https://github.com/$uname/codea.git
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4dbb1a3f2041> in <module>()
# ----> 1 password = getpass('Github Password : ')
#       2 get_ipython().system('git remote set-url origin https://$uname:$password@github.com/$uname/codea.git')
#       3 get_ipython().system('git commit -am "Modif setup.ipynb"')
#       4 get_ipython().system('git push origin master')
#       5
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     685             self._parent_ident,
#     686             self._parent_header,
# --> 687             password=True,
#     688         )
#     689
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
